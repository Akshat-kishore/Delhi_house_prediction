# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv('MagicBricks.csv')

# %%
data.head()
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor       NaN
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment    6667.0
# 3  Ready_to_move        Resale  Builder_Floor    6667.0
# ...

# %%
data.shape
# Out:
# (1259, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1259 non-null   float64
#  1   BHK          1259 non-null   int64
#  2   Bathroom     1257 non-null   float64
#  3   Furnishing   1254 non-null   object
#  4   Locality     1259 non-null   object
#  5   Parking      1226 non-null   float64
#  6   Price        1259 non-null   int64
#  7   Status       1259 non-null   object
#  8   Transaction  1259 non-null   object
#  9   Type         1254 non-null   object
#  10  Per_Sqft     1018 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 108.3+ KB

# %%
for column in data.columns:
    print(data[column].value_counts())
    print('='*30)
# Out:
# 900.0      67
# 1500.0     50
# 1800.0     48
# 1000.0     42
# 1600.0     38
#            ..
# 150.0       1
# 3250.0      1
# 4000.0      1
# 5500.0      1
# 11050.0     1
# Name: Area, Length: 315, dtype: int64
# ...
# 3     541
# 2     367
# 4     220
# 1      96
# 5      27
# 6       6
# 7       1
# 10      1
# Name: BHK, dtype: int64
# ...
# 2.0    551
# 3.0    355
# 1.0    146
# 4.0    138
# 5.0     57
# 6.0      7
# 7.0      3
# Name: Bathroom, dtype: int64
# ...
# Semi-Furnished    708
# Unfurnished       363
# Furnished         183
# Name: Furnishing, dtype: int64
# ...

# %%
data.isna().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         2
# Furnishing       5
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# dtype: int64

# %%
data.describe()
# Out:
#                Area          BHK     Bathroom      Parking         Price  \
# count   1259.000000  1259.000000  1257.000000  1226.000000  1.259000e+03
# mean    1466.452724     2.796664     2.556086     1.935563  2.130670e+07
# std     1568.055040     0.954425     1.042220     6.279212  2.560115e+07
# min       28.000000     1.000000     1.000000     1.000000  1.000000e+06
# 25%      800.000000     2.000000     2.000000     1.000000  5.700000e+06
# 50%     1200.000000     3.000000     2.000000     1.000000  1.420000e+07
# 75%     1700.000000     3.000000     3.000000     2.000000  2.550000e+07
# max    24300.000000    10.000000     7.000000   114.000000  2.400000e+08
#
#             Per_Sqft
# count    1018.000000
# mean    15690.136542
# std     21134.738568
# min      1259.000000
# 25%      6364.000000
# 50%     11291.500000
# 75%     18000.000000
# max    183333.000000

# %%
data.drop(columns=["Area","Parking"],inplace=True)

# %%
data.describe()
# Out:
#                BHK     Bathroom         Price       Per_Sqft
# count  1259.000000  1257.000000  1.259000e+03    1018.000000
# mean      2.796664     2.556086  2.130670e+07   15690.136542
# std       0.954425     1.042220  2.560115e+07   21134.738568
# min       1.000000     1.000000  1.000000e+06    1259.000000
# 25%       2.000000     2.000000  5.700000e+06    6364.000000
# 50%       3.000000     2.000000  1.420000e+07   11291.500000
# 75%       3.000000     3.000000  2.550000e+07   18000.000000
# max      10.000000     7.000000  2.400000e+08  183333.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   BHK          1259 non-null   int64
#  1   Bathroom     1257 non-null   float64
#  2   Furnishing   1254 non-null   object
#  3   Locality     1259 non-null   object
#  4   Price        1259 non-null   int64
#  5   Status       1259 non-null   object
#  6   Transaction  1259 non-null   object
#  7   Type         1254 non-null   object
#  8   Per_Sqft     1018 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 88.6+ KB

# %%
data['Locality'].value_counts()
# Out:
# Lajpat Nagar 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  34
# ...

# %%
data['Bathroom'].value_counts()
# Out:
# 2.0    551
# 3.0    355
# 1.0    146
# 4.0    138
# 5.0     57
# 6.0      7
# 7.0      3
# Name: Bathroom, dtype: int64

# %%
data['Furnishing'].value_counts()
# Out:
# Semi-Furnished    708
# Unfurnished       363
# Furnished         183
# Name: Furnishing, dtype: int64

# %%
data['Price'].value_counts()
# Out:
# 15000000     30
# 25000000     21
# 30000000     21
# 6000000      20
# 20000000     20
#              ..
# 135500000     1
# 8770000       1
# 74000000      1
# 120000000     1
# 22200000      1
# Name: Price, Length: 284, dtype: int64

# %%
data['Status'].value_counts()
# Out:
# Ready_to_move    1184
# Almost_ready       75
# Name: Status, dtype: int64

# %%
data['Transaction'].value_counts()
# Out:
# Resale          781
# New_Property    478
# Name: Transaction, dtype: int64

# %%
data['Type'].value_counts()
# Out:
# Builder_Floor    661
# Apartment        593
# Name: Type, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   BHK          1259 non-null   int64
#  1   Bathroom     1257 non-null   float64
#  2   Furnishing   1254 non-null   object
#  3   Locality     1259 non-null   object
#  4   Price        1259 non-null   int64
#  5   Status       1259 non-null   object
#  6   Transaction  1259 non-null   object
#  7   Type         1254 non-null   object
#  8   Per_Sqft     1018 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 88.6+ KB

# %%
data['Per_Sqft'].unique()
# Out:
# array([    nan,   6667.,   6154.,   6364.,   8750.,   9722.,  14444.,
#         22000.,   2235.,   3800.,   4247.,   3524.,  26666.,  15972.,
#        183333.,  20000.,  15556.,  16176.,   9259.,  18507.,   7000.,
#         72000.,  43000.,   4444.,   3300.,  40000.,   5185.,   4000.,
#          3567.,   1259.,   2500.,   5255.,   6528.,   6875.,   5714.,
#          7449.,   8125.,   7931.,   5789.,   6471.,   8438.,   6508.,
#          8000.,   6000.,   6250.,   6333.,   6714.,  28797.,  23840.,
#          4600.,   4620.,   5000.,   6111.,  25512.,  22222.,  24718.,
#         30556.,  18750., 120000.,  15459.,  23529.,  16667.,  11111.,
#         21409.,  95000.,  15363.,  19259.,  20833.,  20930.,   6526.,
#          3901.,   6347.,  41304.,   8701.,   5556.,  85715.,   6944.,
#          7222.,  11220.,   5357.,   6706.,  10288.,  28283.,   8923.,
#          8222.,  14550.,  30093.,  35714.,  22857.,  12500.,   4040.,
# ...

# %%
data.describe()
# Out:
#                BHK     Bathroom         Price       Per_Sqft
# count  1259.000000  1257.000000  1.259000e+03    1018.000000
# mean      2.796664     2.556086  2.130670e+07   15690.136542
# std       0.954425     1.042220  2.560115e+07   21134.738568
# min       1.000000     1.000000  1.000000e+06    1259.000000
# 25%       2.000000     2.000000  5.700000e+06    6364.000000
# 50%       3.000000     2.000000  1.420000e+07   11291.500000
# 75%       3.000000     3.000000  2.550000e+07   18000.000000
# max      10.000000     7.000000  2.400000e+08  183333.000000

# %%
print("Price per sqft")
# Out:
# Price per sqft

# %%
data['price_per_sqft']=data['Price']*100000/data['Per_Sqft']

# %%
data['price_per_sqft']
# Out:
# 0                NaN
# 1       7.499625e+07
# 2       2.324884e+08
# 3       6.299685e+07
# 4       9.299535e+07
#             ...
# 1254    4.258284e+08
# 1255    9.677919e+07
# 1256    1.354909e+08
# 1257    8.903685e+07
# 1258    1.432332e+08
# Name: price_per_sqft, Length: 1259, dtype: float64

# %%
data.price_per_sqft.describe()
# Out:
# count    1.018000e+03
# mean     1.736812e+08
# std      2.126807e+08
# min      3.499971e+06
# 25%      6.306890e+07
# 50%      1.200021e+08
# 75%      2.125053e+08
# max      3.131991e+09
# Name: price_per_sqft, dtype: float64

# %%
x=data.drop(columns=['Price'])
y=data['Price']

# %%
import sklearn as sk
from sklearn.linear_model import LinearRegression
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (1007, 9)
# (252, 9)

# %% [markdown]
# colummn_trans=make_column_transformer((OneHotEncoder(sparse=False),['location']),remainder='passthrough')

# %%
colummn_trans=make_column_transformer((OneHotEncoder(sparse=False),['location']),remainder='passthrough')

# %%
from sklearn.model_selection import train_test_split

# %%
lr=LinearRegression()

# %%
pipe = make_pipeline(scaler, lr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 pipe = make_pipeline(scaler, lr)
#
# NameError: name 'scaler' is not defined

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
pipe.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 pipe.fit(x_train,y_train)
#
# NameError: name 'pipe' is not defined

# %%
sns.pairplot(data)

# %%
pip install pandas-profiling
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/324.4 kB ? eta -:--:--
#      ----------------------------- -------- 256.0/324.4 kB 7.9 MB/s eta 0:00:01
#      -------------------------------------- 324.4/324.4 kB 6.7 MB/s eta 0:00:00
# ...
#   Obtaining dependency information for ydata-profiling from https://files.pythonhosted.org/packages/09/98/5a5fbfd48bf23acd3ceed5114d073b877965816304078151fefbf86d8458/ydata_profiling-4.5.1-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for pydantic<2,>=1.8.1 from https://files.pythonhosted.org/packages/0e/88/8e503b95402c73e023d705293ff0659f133976cdd726f7f8dffce5e8eef4/pydantic-1.10.12-cp310-cp310-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/150.6 kB ? eta -:--:--
#      -------------------------------------- 150.6/150.6 kB 8.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/102.7 kB ? eta -:--:--
#      -------------------------------------- 102.7/102.7 kB 5.8 MB/s eta 0:00:00
# ...

# %%
from pandas_profiling import ProfileReport
prof=ProfileReport(data)
prof.to_file(output_file='output.html')
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5100\1304624114.py:1: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
